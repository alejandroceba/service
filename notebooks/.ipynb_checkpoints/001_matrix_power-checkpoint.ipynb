# %%
import numpy as np
from numpy.linalg import matrix_power

# %%
6/11
# Out:
# 0.5454545454545454

# %%
T = np.array([
    [.75,.2],
    [.25,.8],
])

# %%
Tn = matrix_power(T,49)
Tn
# Out:
# array([[0.44444444, 0.44444444],
#        [0.55555556, 0.55555556]])

# %%
S0 = np.array([
    [81],
    [45]
])

# %%
Tn @ S0
# Out:
# array([[56.],
#        [70.]])

# %%
T5 = matrix_power(T,5)
T5
# Out:
# array([[0.82282369, 0.13828395],
#        [0.17717631, 0.86171605]])

# %%
A = np.array([
    [45520],
    [38745]
])

# %%
N = T5 @ A
N
# Out:
# array([[42812.74604672],
#        [41452.25395328]])

# %%
(42812.74604672 - 41452.25395328) / (45520 + 38745)
# Out:
# 0.016145399554263334
