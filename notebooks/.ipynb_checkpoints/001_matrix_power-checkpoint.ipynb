# %%
import numpy as np
from numpy.linalg import matrix_power

# %%
T = np.array([
    [.92,.12],
    [.08,.88],
])

# %%
S0 = np.array([
    [24500],
    [45200]
])

# %%
T @ P0
# Out:
# array([[27964.],
#        [41736.]])

# %%
Tn = matrix_power(T,49)
Tn
# Out:
# array([[0.44444444, 0.44444444],
#        [0.55555556, 0.55555556]])

# %%
TN = np.array([
    [.6,.6],
    [.4,.4]
])

# %%
TN @ S0
# Out:
# array([[41820.],
#        [27880.]])
